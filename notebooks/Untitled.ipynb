# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
ds = xr.open_dataset('../results/piClim-control/od550dust/od550dust_piClim-control_MPI-ESM-1-2-HAM_clim.nc')

# %%
fig,ax = plt.subplots(subplot_kw={'projection':ccrs.PlateCarree()})
ds['od550dust'].isel(month=0).plot(ax=ax)
ax.coastlines()

# %%
xr.open_dataset('/home/oveh/mnt/Betzy_CMIP/CMIP6/RFMIP/HAMMOZ-Consortium/MPI-ESM-1-2-HAM/piClim-control/r1i1p1f1/AERmon/od550dust/gn/latest/od550dust_AERmon_MPI-ESM-1-2-HAM_piClim-control_r1i1p1f1_gn_185001-186912.nc')
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 240, bnds: 2, lat: 96, lon: 192)
# Coordinates:
#   * time        (time) datetime64[ns] 1850-01-16T12:00:00 ... 1869-12-16T12:0...
#   * lat         (lat) float64 -88.57 -86.72 -84.86 -83.0 ... 84.86 86.72 88.57
#   * lon         (lon) float64 0.0 1.875 3.75 5.625 ... 352.5 354.4 356.2 358.1
#     wavelength  float64 ...
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds   (time, bnds) datetime64[ns] ...
#     lat_bnds    (lat, bnds) float64 ...
#     lon_bnds    (lon, bnds) float64 ...
#     od550dust   (time, lat, lon) float32 ...
# Attributes: (12/47)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            RFMIP AerChemMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  36524.0
#     contact:                david.neubauer@env.ethz.ch
#     ...                     ...
#     title:                  MPI-ESM-1-2-HAM output prepared for CMIP6
# ...
