# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import sys
import xarray as xr
import os
sys.path.append(os.path.dirname('../workflow'))
from workflow.scripts.plotting_tools import global_map
import matplotlib.patches as mpatch
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/envs/geocat/share/proj failed

# %%
fig,ax = plt.subplots(1,1,subplot_kw={'projection':ccrs.PlateCarree()}, figsize=(10,8))
global_map(ax)

ax.add_artist(mpatch.Rectangle(xy=[-14,10], width=50, height=21, transform=ccrs.PlateCarree(), 
    facecolor='none', edgecolor='tab:purple', linewidth=1.5,linestyle='-.', zorder=10))

ax.add_artist(mpatch.Rectangle(xy=[-66,-6], width=50, height=40, transform=ccrs.PlateCarree(), 
    facecolor='none', edgecolor='tab:pink', linewidth=1.5,linestyle='-.', zorder=10))


ax.add_artist(mpatch.Rectangle(xy=[37,19], width=42, height=18, transform=ccrs.PlateCarree(), 
    facecolor='none', edgecolor='tab:green', linewidth=1.5,linestyle='-.', zorder=10))


ax.add_artist(mpatch.Rectangle(xy=[42,-6], width=40, height=25, transform=ccrs.PlateCarree(), 
    facecolor='none', edgecolor='tab:orange', linewidth=1.5,linestyle='-.', zorder=10))



ax.add_artist(mpatch.Rectangle(xy=[79,23], width=38, height=28, transform=ccrs.PlateCarree(), 
    facecolor='none', edgecolor='tab:blue', linewidth=1.5,linestyle='-.', zorder=10))



ax.add_artist(mpatch.Rectangle(xy=[117,15], width=30, height=33, transform=ccrs.PlateCarree(), 
    facecolor='none', edgecolor='tab:red', linewidth=1.5,linestyle='-.', zorder=10))
